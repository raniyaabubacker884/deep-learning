# %% [markdown]
# <a href="https://colab.research.google.com/github/raniyaabubacker884/deep-learning/blob/main/day1_scientific_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.DataFrame({
    'Name': ['Asha','Ravi','Neha','kiran'],
    'Age' : [22,25,28,30],
    'Marks': [80,85,90,88],
}, index=[1,2,3,4])

# %%
df
# Out:
#     Name  Age  Marks
# 1   Asha   22     80
# 2   Ravi   25     85
# 3   Neha   28     90
# 4  kiran   30     88

# %%
data = {
    'Name': ['Alice','Bob','Charlie'],
    'Age' : [25,30,35],
    'Salary': [50000,60000,70000],
    'Department':['IT','HR','IT']
}
df=pd.DataFrame(data)
print(df)
# Out:
#       Name  Age  Salary Department
# 0    Alice   25   50000         IT
# 1      Bob   30   60000         HR
# 2  Charlie   35   70000         IT

# %%
df=pd.read_csv("/content/sales_data_sample (1).csv",encoding='latin1')
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
df.tail()
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#            ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 2818  12/2/2004 0:00   Shipped       4        12     2004  ...
# 2819  1/31/2005 0:00   Shipped       1         1     2005  ...
# 2820   3/1/2005 0:00  Resolved       1         3     2005  ...
# 2821  3/28/2005 0:00   Shipped       1         3     2005  ...
# 2822   5/6/2005 0:00   On Hold       2         5     2005  ...
#
#                ADDRESSLINE1  ADDRESSLINE2      CITY STATE POSTALCODE  COUNTRY  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %%
df.shape
# Out:
# (2823, 25)

# %%
df.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %%
df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000  2823.000000      2823.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.085478         9.741443    20.174277         4.225841
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               SALES       QTR_ID     MONTH_ID     YEAR_ID         MSRP
# count   2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3553.889072     2.717676     7.092455  2003.81509   100.715551
# std     1841.865106     1.203878     3.656633     0.69967    40.187912
# min      482.130000     1.000000     1.000000  2003.00000    33.000000
# ...

# %%
df.isnull()
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER  SALES  \
# 0           False            False      False            False  False
# 1           False            False      False            False  False
# 2           False            False      False            False  False
# 3           False            False      False            False  False
# 4           False            False      False            False  False
# ...           ...              ...        ...              ...    ...
# 2818        False            False      False            False  False
# 2819        False            False      False            False  False
# 2820        False            False      False            False  False
# 2821        False            False      False            False  False
# 2822        False            False      False            False  False
#
#       ORDERDATE  STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  ADDRESSLINE1  \
# ...

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2818    False
# 2819    False
# 2820    False
# 2821    False
# 2822    False
# Length: 2823, dtype: bool

# %%
df['COUNTRY']
# Out:
# 0           USA
# 1        France
# 2        France
# 3           USA
# 4           USA
#          ...
# 2818      Spain
# 2819    Finland
# 2820      Spain
# 2821     France
# 2822        USA
# Name: COUNTRY, Length: 2823, dtype: object

# %%
df[['POSTALCODE','COUNTRY']]
# Out:
#      POSTALCODE  COUNTRY
# 0         10022      USA
# 1         51100   France
# 2         75508   France
# 3         90003      USA
# 4           NaN      USA
# ...         ...      ...
# 2818      28034    Spain
# 2819      90110  Finland
# 2820      28034    Spain
# 2821      31000   France
# 2822      51003      USA
#
# [2823 rows x 2 columns]

# %%
df[['COUNTRY','STATE']]
# Out:
#       COUNTRY STATE
# 0         USA    NY
# 1      France   NaN
# 2      France   NaN
# 3         USA    CA
# 4         USA    CA
# ...       ...   ...
# 2818    Spain   NaN
# 2819  Finland   NaN
# 2820    Spain   NaN
# 2821   France   NaN
# 2822      USA    MA
#
# [2823 rows x 2 columns]

# %%
df[['TERRITORY','STATE','ORDERNUMBER']]
# Out:
#      TERRITORY STATE  ORDERNUMBER
# 0          NaN    NY        10107
# 1         EMEA   NaN        10121
# 2         EMEA   NaN        10134
# 3          NaN    CA        10145
# 4          NaN    CA        10159
# ...        ...   ...          ...
# 2818      EMEA   NaN        10350
# 2819      EMEA   NaN        10373
# 2820      EMEA   NaN        10386
# 2821      EMEA   NaN        10397
# 2822       NaN    MA        10414
#
# [2823 rows x 3 columns]

# %%
df[20:]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 20          10341               41     100.00                9  7737.93
# 21          10361               20      72.55               13  1451.00
# 22          10375               21      34.91               12   733.11
# 23          10388               42      76.36                4  3207.12
# 24          10403               24     100.00                7  2434.56
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df[20:25]
# Out:
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 20        10341               41     100.00                9  7737.93
# 21        10361               20      72.55               13  1451.00
# 22        10375               21      34.91               12   733.11
# 23        10388               42      76.36                4  3207.12
# 24        10403               24     100.00                7  2434.56
#
#           ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 20  11/24/2004 0:00  Shipped       4        11     2004  ...
# 21  12/17/2004 0:00  Shipped       4        12     2004  ...
# 22    2/3/2005 0:00  Shipped       1         2     2005  ...
# 23    3/3/2005 0:00  Shipped       1         3     2005  ...
# 24    4/8/2005 0:00  Shipped       2         4     2005  ...
#
#                                ADDRESSLINE1  ADDRESSLINE2         CITY STATE  \
# 20                              Geislweg 14           NaN     Salzburg   NaN
# ...

# %%
df['COUNTRY'].value_counts()
# Out:
# COUNTRY
# USA            1004
# Spain           342
# France          314
# Australia       185
# UK              144
# Italy           113
# Finland          92
# Norway           85
# Singapore        79
# Canada           70
# Denmark          63
# Germany          62
# Sweden           57
# Austria          55
# Japan            52
# Belgium          33
# Switzerland      31
# Philippines      26
# Ireland          16
# Name: count, dtype: int64

# %%
df['COUNTRY'].unique()
# Out:
# array(['USA', 'France', 'Norway', 'Australia', 'Finland', 'Austria', 'UK',
#        'Spain', 'Sweden', 'Singapore', 'Canada', 'Japan', 'Italy',
#        'Denmark', 'Belgium', 'Philippines', 'Germany', 'Switzerland',
#        'Ireland'], dtype=object)

# %%
df['COUNTRY'].nunique()
# Out:
# 19

# %%
df['CITY'].unique()
# Out:
# array(['NYC', 'Reims', 'Paris', 'Pasadena', 'San Francisco', 'Burlingame',
#        'Lille', 'Bergen', 'Melbourne', 'Newark', 'Bridgewater', 'Nantes',
#        'Cambridge', 'Helsinki', 'Stavern', 'Allentown', 'Salzburg',
#        'Chatswood', 'New Bedford', 'Liverpool', 'Madrid', 'Lule',
#        'Singapore', 'South Brisbane', 'Philadelphia', 'Lyon', 'Vancouver',
#        'Burbank', 'New Haven', 'Minato-ku', 'Torino', 'Boras',
#        'Versailles', 'San Rafael', 'Nashua', 'Brickhaven', 'North Sydney',
#        'Montreal', 'Osaka', 'White Plains', 'Kobenhavn', 'London',
#        'Toulouse', 'Barcelona', 'Los Angeles', 'San Diego', 'Bruxelles',
#        'Tsawassen', 'Boston', 'Cowes', 'Oulu', 'San Jose', 'Graz',
#        'Makati City', 'Marseille', 'Koln', 'Gensve', 'Reggio Emilia',
#        'Frankfurt', 'Espoo', 'Dublin', 'Manchester', 'Aaarhus',
#        'Glendale', 'Sevilla', 'Brisbane', 'Strasbourg', 'Las Vegas',
#        'Oslo', 'Bergamo', 'Glen Waverly', 'Munich', 'Charleroi'],
# ...

# %%
df['CITY'].nunique()
# Out:
# 73

# %%
df.loc[0]
# Out:
# ORDERNUMBER                           10107
# QUANTITYORDERED                          30
# PRICEEACH                              95.7
# ORDERLINENUMBER                           2
# SALES                                2871.0
# ORDERDATE                    2/24/2003 0:00
# STATUS                              Shipped
# QTR_ID                                    1
# MONTH_ID                                  2
# YEAR_ID                                2003
# PRODUCTLINE                     Motorcycles
# MSRP                                     95
# PRODUCTCODE                        S10_1678
# CUSTOMERNAME              Land of Toys Inc.
# PHONE                            2125557818
# ADDRESSLINE1        897 Long Airport Avenue
# ADDRESSLINE2                            NaN
# CITY                                    NYC
# STATE                                    NY
# POSTALCODE                            10022
# COUNTRY                                 USA
# ...

# %%
df.loc[25,'ORDERDATE']
# Out:
# '5/13/2005 0:00'

# %%
df.loc[25,['STATE','TERRITORY']]
# Out:
# STATE         NaN
# TERRITORY    EMEA
# Name: 25, dtype: object

# %%
df.iloc[0:50,2]
# Out:
# 0      95.70
# 1      81.35
# 2      94.74
# 3      83.26
# 4     100.00
# 5      96.66
# 6      86.13
# 7     100.00
# 8      98.57
# 9     100.00
# 10    100.00
# 11    100.00
# 12    100.00
# 13    100.00
# 14     92.83
# 15    100.00
# 16    100.00
# 17    100.00
# 18     94.74
# 19    100.00
# 20    100.00
# 21     72.55
# 22     34.91
# 23     76.36
# 24    100.00
# 25    100.00
# 26    100.00
# 27    100.00
# 28    100.00
# 29    100.00
# 30    100.00
# 31    100.00
# 32    100.00
# 33    100.00
# 34    100.00
# 35    100.00
# 36    100.00
# 37    100.00
# 38    100.00
# 39    100.00
# 40    100.00
# 41    100.00
# 42    100.00
# 43    100.00
# 44    100.00
# 45    100.00
# 46    100.00
# 47    100.00
# 48    100.00
# 49    100.00
# Name: PRICEEACH, dtype: float64

# %%
df.iloc[10:23,5]
# Out:
# 10     2/20/2004 0:00
# 11      4/5/2004 0:00
# 12     5/18/2004 0:00
# 13     6/28/2004 0:00
# 14     7/23/2004 0:00
# 15     8/27/2004 0:00
# 16     9/30/2004 0:00
# 17    10/15/2004 0:00
# 18     11/2/2004 0:00
# 19    11/15/2004 0:00
# 20    11/24/2004 0:00
# 21    12/17/2004 0:00
# 22      2/3/2005 0:00
# Name: ORDERDATE, dtype: object

# %%
df.iloc[0:30,[0,3,2]]
# Out:
#     ORDERNUMBER  ORDERLINENUMBER  PRICEEACH
# 0         10107                2      95.70
# 1         10121                5      81.35
# 2         10134                2      94.74
# 3         10145                6      83.26
# 4         10159               14     100.00
# 5         10168                1      96.66
# 6         10180                9      86.13
# 7         10188                1     100.00
# 8         10201                2      98.57
# 9         10211               14     100.00
# 10        10223                1     100.00
# 11        10237                7     100.00
# 12        10251                2     100.00
# 13        10263                2     100.00
# 14        10275                1      92.83
# 15        10285                6     100.00
# 16        10299                9     100.00
# 17        10309                5     100.00
# 18        10318                1      94.74
# 19        10329                1     100.00
# ...

# %%
df.iloc[0:23,[14,17,20]]
# Out:
#                PHONE           CITY    COUNTRY
# 0         2125557818            NYC        USA
# 1         26.47.1555          Reims     France
# 2   +33 1 46 62 7555          Paris     France
# 3         6265557265       Pasadena        USA
# 4         6505551386  San Francisco        USA
# 5         6505556809     Burlingame        USA
# 6         20.16.1555          Lille     France
# 7      +47 2267 3215         Bergen     Norway
# 8         6505555787  San Francisco        USA
# 9     (1) 47.55.6555          Paris     France
# 10      03 9520 4555      Melbourne  Australia
# 11        2125551500            NYC        USA
# 12        2015559350         Newark        USA
# 13        2035552570    Bridgewater        USA
# 14        40.67.8555         Nantes     France
# 15        6175558555      Cambridge        USA
# 16       90-224 8555       Helsinki    Finland
# 17        07-98 9555        Stavern     Norway
# 18        2155551555      Allentown        USA
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.rename(columns={'STATE':'STATE_NAME'},inplace=True)
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df['ORDERDATE']
# Out:
# 0        2/24/2003 0:00
# 1         5/7/2003 0:00
# 2         7/1/2003 0:00
# 3        8/25/2003 0:00
# 4       10/10/2003 0:00
#              ...
# 2818     12/2/2004 0:00
# 2819     1/31/2005 0:00
# 2820      3/1/2005 0:00
# 2821     3/28/2005 0:00
# 2822      5/6/2005 0:00
# Name: ORDERDATE, Length: 2823, dtype: object

# %%
df['ORDERDATE']=pd.to_datetime(df['ORDERDATE'])
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#       ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df['ORDERDATE']
# Out:
# 0      2003-02-24
# 1      2003-05-07
# 2      2003-07-01
# 3      2003-08-25
# 4      2003-10-10
#           ...
# 2818   2004-12-02
# 2819   2005-01-31
# 2820   2005-03-01
# 2821   2005-03-28
# 2822   2005-05-06
# Name: ORDERDATE, Length: 2823, dtype: datetime64[ns]

# %%
df['year']=df['ORDERDATE'].dt.year
df['year']
# Out:
# 0       2003
# 1       2003
# 2       2003
# 3       2003
# 4       2003
#         ...
# 2818    2004
# 2819    2005
# 2820    2005
# 2821    2005
# 2822    2005
# Name: year, Length: 2823, dtype: int32

# %%
df['day']=df['ORDERDATE'].dt.day
df['day']
# Out:
# 0       24
# 1        7
# 2        1
# 3       25
# 4       10
#         ..
# 2818     2
# 2819    31
# 2820     1
# 2821    28
# 2822     6
# Name: day, Length: 2823, dtype: int32

# %%
df['PROFIT_EST']=df['SALES']*0.2
df['PROFIT_EST']
# Out:
# 0        574.200
# 1        553.180
# 2        776.868
# 3        749.340
# 4       1041.054
#           ...
# 2818     448.880
# 2819     795.702
# 2820    1083.514
# 2821     423.232
# 2822     615.888
# Name: PROFIT_EST, Length: 2823, dtype: float64

# %%
df.drop('PROFIT_EST',axis=1,inplace=True)

# %%
df['FULL_NAME']=df['CONTACTFIRSTNAME']+' '+df['CONTACTLASTNAME']

# %%
monthly_sales=df.groupby('MONTH_ID')['SALES'].sum()
print(monthly_sales)
# Out:
# MONTH_ID
# 1      785874.44
# 2      810441.90
# 3      754501.39
# 4      669390.96
# 5      923972.56
# 6      454756.78
# 7      514875.97
# 8      659310.57
# 9      584724.27
# 10    1121215.22
# 11    2118885.67
# 12     634679.12
# Name: SALES, dtype: float64

# %%
monthly_sales.plot(kind='line')
# Out:
# <Axes: xlabel='MONTH_ID'>

# %%
monthly_sales.plot(kind='bar')
# Out:
# <Axes: xlabel='MONTH_ID'>

# %%
df.groupby('COUNTRY')['SALES'].sum()
# Out:
# COUNTRY
# Australia       630623.10
# Austria         202062.53
# Belgium         108412.62
# Canada          224078.56
# Denmark         245637.15
# Finland         329581.91
# France         1110916.52
# Germany         220472.09
# Ireland          57756.43
# Italy           374674.31
# Japan           188167.81
# Norway          307463.70
# Philippines      94015.73
# Singapore       288488.41
# Spain          1215686.92
# Sweden          210014.21
# Switzerland     117713.56
# UK              478880.46
# USA            3627982.83
# Name: SALES, dtype: float64

# %%
orders_per_year=df.groupby('YEAR_ID')['ORDERNUMBER'].nunique()
print(orders_per_year)
# Out:
# YEAR_ID
# 2003    104
# 2004    144
# 2005     59
# Name: ORDERNUMBER, dtype: int64

# %%
avg_sales_product=df.groupby('PRODUCTCODE')['SALES'].mean().sort_values(ascending=False)
print(avg_sales_product)
# Out:
# PRODUCTCODE
# S10_1949    6824.036786
# S10_4698    6553.887308
# S12_1108    6484.050769
# S18_1749    5786.837273
# S18_2238    5726.812963
#                ...
# S24_2022    1786.686400
# S24_2972    1722.811852
# S24_2840    1686.981429
# S32_2206    1654.137200
# S24_3969    1508.257273
# Name: SALES, Length: 109, dtype: float64

# %%
df['DEALSIZE']=df['DEALSIZE'].str.upper()
df['DEALSIZE']
# Out:
# 0        SMALL
# 1        SMALL
# 2       MEDIUM
# 3       MEDIUM
# 4       MEDIUM
#          ...
# 2818     SMALL
# 2819    MEDIUM
# 2820    MEDIUM
# 2821     SMALL
# 2822    MEDIUM
# Name: DEALSIZE, Length: 2823, dtype: object

# %%
df.to_csv('cleaned_data.csv',index=False)

# %%
import pandas as pd
df=pd.read_csv('/content/Zudio_sales_data.csv')
df
# Out:
#       Store Country          State        City Category Clothing Type  \
# 0     Zudio   India      Karnataka       Jalna    Women       Dresses
# 1     Zudio   India        Gujarat       Patna     Kids        Skirts
# 2     Zudio   India  Uttar Pradesh     Kolkata      Men       Hoodies
# 3     Zudio   India    West Bengal     Kolkata    Women       Dresses
# 4     Zudio   India    West Bengal    Guwahati      Men       Dresses
# ...     ...     ...            ...         ...      ...           ...
# 7894  Zudio   India  Uttar Pradesh  Chandigarh     Kids         Jeans
# 7895  Zudio   India  Uttar Pradesh  Aurangabad     Kids       Jackets
# 7896  Zudio   India     Tamil Nadu        Pune     Kids      T-shirts
# 7897  Zudio   India          Delhi     Madurai      Men         Shoes
# 7898  Zudio   India        Gujarat   Bengaluru    Women        Shirts
#
#       Store Number  Postal Code Store Type Store Open Date  ...  \
# ...

# %%
df.head()
# Out:
#    Store Country          State      City Category Clothing Type  \
# 0  Zudio   India      Karnataka     Jalna    Women       Dresses
# 1  Zudio   India        Gujarat     Patna     Kids        Skirts
# 2  Zudio   India  Uttar Pradesh   Kolkata      Men       Hoodies
# 3  Zudio   India    West Bengal   Kolkata    Women       Dresses
# 4  Zudio   India    West Bengal  Guwahati      Men       Dresses
#
#    Store Number  Postal Code Store Type Store Open Date  ...  \
# 0            30       411084      Owned      2022-06-04  ...
# 1            48       404562      Owned      2020-12-19  ...
# 2            97       437773     Rented      2023-09-04  ...
# 3            93       431725      Owned      2024-04-11  ...
# 4            51       415370      Owned      2022-05-29  ...
#
#    Security Features Order ID  Order Date     Month Customer ID  \
# 0              Alarm    88240  2024-11-06  November      233084
# 1              Alarm    78145  2024-06-17      June      926472
# ...

# %%
df.tail()
# Out:
#       Store Country          State        City Category Clothing Type  \
# 7894  Zudio   India  Uttar Pradesh  Chandigarh     Kids         Jeans
# 7895  Zudio   India  Uttar Pradesh  Aurangabad     Kids       Jackets
# 7896  Zudio   India     Tamil Nadu        Pune     Kids      T-shirts
# 7897  Zudio   India          Delhi     Madurai      Men         Shoes
# 7898  Zudio   India        Gujarat   Bengaluru    Women        Shirts
#
#       Store Number  Postal Code Store Type Store Open Date  ...  \
# 7894            32       431437      Owned      2024-04-24  ...
# 7895            52       424643      Owned      2024-02-03  ...
# 7896            81       412057      Owned      2021-04-11  ...
# 7897            58       405203     Rented      2022-06-17  ...
# 7898            20       429823      Owned      2023-02-08  ...
#
#       Security Features Order ID  Order Date      Month Customer ID  \
# 7894        CCTV, Alarm    39056  2024-09-27  September      591993
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7899 entries, 0 to 7898
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Store                      7899 non-null   object
#  1   Country                    7899 non-null   object
#  2   State                      7899 non-null   object
#  3   City                       7899 non-null   object
#  4   Category                   7899 non-null   object
#  5   Clothing Type              7899 non-null   object
#  6   Store Number               7899 non-null   int64
#  7   Postal Code                7899 non-null   int64
#  8   Store Type                 7899 non-null   object
#  9   Store Open Date            7899 non-null   object
#  10  Selling Area Size (sq ft)  7899 non-null   int64
#  11  Store Manager              7899 non-null   object
#  12  Manager ID                 7899 non-null   object
# ...

# %%
df.shape
# Out:
# (7899, 28)

# %%
df.columns
# Out:
# Index(['Store', 'Country', 'State', 'City', 'Category', 'Clothing Type',
#        'Store Number', 'Postal Code', 'Store Type', 'Store Open Date',
#        'Selling Area Size (sq ft)', 'Store Manager', 'Manager ID',
#        'Store Address', 'Contact Information', 'Operating Hours',
#        'Staff Count', 'Parking Availability', 'Security Features', 'Order ID',
#        'Order Date', 'Month', 'Customer ID', 'Customer Name', 'Product ID',
#        'Price', 'Quantity', 'Sales Profit'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Store Number    Postal Code  Selling Area Size (sq ft)  Staff Count  \
# count   7899.000000    7899.000000                7899.000000  7899.000000
# mean      50.666034  419982.374984                1112.077478    11.504747
# std       29.095274   11695.237817                 193.239371     5.194722
# min        1.000000  400006.000000                 800.000000     3.000000
# 25%       25.000000  409841.000000                 950.000000     7.000000
# 50%       51.000000  419988.000000                1100.000000    12.000000
# 75%       76.000000  430258.000000                1300.000000    16.000000
# max      100.000000  439985.000000                1400.000000    20.000000
#
#            Order ID    Customer ID   Product ID        Price     Quantity  \
# count   7899.000000    7899.000000  7899.000000  7899.000000  7899.000000
# mean   54920.719965  549440.714521   602.069376  1761.113432     4.519433
# ...

# %%
df.isnull()
# Out:
#       Store  Country  State   City  Category  Clothing Type  Store Number  \
# 0     False    False  False  False     False          False         False
# 1     False    False  False  False     False          False         False
# 2     False    False  False  False     False          False         False
# 3     False    False  False  False     False          False         False
# 4     False    False  False  False     False          False         False
# ...     ...      ...    ...    ...       ...            ...           ...
# 7894  False    False  False  False     False          False         False
# 7895  False    False  False  False     False          False         False
# 7896  False    False  False  False     False          False         False
# 7897  False    False  False  False     False          False         False
# 7898  False    False  False  False     False          False         False
#
#       Postal Code  Store Type  Store Open Date  ...  Security Features  \
# ...

# %%
df.isnull().sum()
# Out:
# Store                           0
# Country                         0
# State                           0
# City                            0
# Category                        0
# Clothing Type                   0
# Store Number                    0
# Postal Code                     0
# Store Type                      0
# Store Open Date                 0
# Selling Area Size (sq ft)       0
# Store Manager                   0
# Manager ID                      0
# Store Address                   0
# Contact Information             0
# Operating Hours                 0
# Staff Count                     0
# Parking Availability            0
# Security Features            2038
# Order ID                        0
# Order Date                      0
# Month                           0
# Customer ID                     0
# Customer Name                   0
# Product ID                      0
# Price                           0
# Quantity                        0
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7894    False
# 7895    False
# 7896    False
# 7897    False
# 7898    False
# Length: 7899, dtype: bool

# %%
df['Store']
# Out:
# 0       Zudio
# 1       Zudio
# 2       Zudio
# 3       Zudio
# 4       Zudio
#         ...
# 7894    Zudio
# 7895    Zudio
# 7896    Zudio
# 7897    Zudio
# 7898    Zudio
# Name: Store, Length: 7899, dtype: object

# %%
df[['Store','City']]
# Out:
#       Store        City
# 0     Zudio       Jalna
# 1     Zudio       Patna
# 2     Zudio     Kolkata
# 3     Zudio     Kolkata
# 4     Zudio    Guwahati
# ...     ...         ...
# 7894  Zudio  Chandigarh
# 7895  Zudio  Aurangabad
# 7896  Zudio        Pune
# 7897  Zudio     Madurai
# 7898  Zudio   Bengaluru
#
# [7899 rows x 2 columns]

# %%
df[['Store','City','Postal Code']]
# Out:
#       Store        City  Postal Code
# 0     Zudio       Jalna       411084
# 1     Zudio       Patna       404562
# 2     Zudio     Kolkata       437773
# 3     Zudio     Kolkata       431725
# 4     Zudio    Guwahati       415370
# ...     ...         ...          ...
# 7894  Zudio  Chandigarh       431437
# 7895  Zudio  Aurangabad       424643
# 7896  Zudio        Pune       412057
# 7897  Zudio     Madurai       405203
# 7898  Zudio   Bengaluru       429823
#
# [7899 rows x 3 columns]

# %%
df[5:]
# Out:
#       Store Country          State        City Category Clothing Type  \
# 5     Zudio   India    West Bengal      Nashik     Kids       Jackets
# 6     Zudio   India    Maharashtra     Lucknow     Kids       Jackets
# 7     Zudio   India    West Bengal   Hyderabad    Women          Tops
# 8     Zudio   India      Karnataka   Ahmedabad      Men         Shoes
# 9     Zudio   India      Karnataka   Hyderabad     Kids         Jeans
# ...     ...     ...            ...         ...      ...           ...
# 7894  Zudio   India  Uttar Pradesh  Chandigarh     Kids         Jeans
# 7895  Zudio   India  Uttar Pradesh  Aurangabad     Kids       Jackets
# 7896  Zudio   India     Tamil Nadu        Pune     Kids      T-shirts
# 7897  Zudio   India          Delhi     Madurai      Men         Shoes
# 7898  Zudio   India        Gujarat   Bengaluru    Women        Shirts
#
#       Store Number  Postal Code Store Type Store Open Date  ...  \
# ...

# %%
df[5:26]
# Out:
#     Store Country          State          City Category Clothing Type  \
# 5   Zudio   India    West Bengal        Nashik     Kids       Jackets
# 6   Zudio   India    Maharashtra       Lucknow     Kids       Jackets
# 7   Zudio   India    West Bengal     Hyderabad    Women          Tops
# 8   Zudio   India      Karnataka     Ahmedabad      Men         Shoes
# 9   Zudio   India      Karnataka     Hyderabad     Kids         Jeans
# 10  Zudio   India    Maharashtra       Kolkata      Men       Hoodies
# 11  Zudio   India  Uttar Pradesh        Nashik      Men       Jackets
# 12  Zudio   India    Maharashtra     Faridabad     Kids         Pants
# 13  Zudio   India        Gujarat         Noida     Kids        Skirts
# 14  Zudio   India     Tamil Nadu       Madurai     Kids      Sweaters
# 15  Zudio   India      Rajasthan         Noida    Women       Dresses
# 16  Zudio   India    Maharashtra  Chhattisgarh      Men         Pants
# ...

# %%
df['State'].value_counts()
# Out:
# State
# Rajasthan        1013
# Uttar Pradesh    1011
# Delhi            1011
# Gujarat           982
# West Bengal       982
# Maharashtra       975
# Karnataka         963
# Tamil Nadu        962
# Name: count, dtype: int64

# %%
df['State'].unique()
# Out:
# array(['Karnataka', 'Gujarat', 'Uttar Pradesh', 'West Bengal',
#        'Maharashtra', 'Tamil Nadu', 'Rajasthan', 'Delhi'], dtype=object)

# %%
df['State'].nunique()
# Out:
# 8

# %%
df.loc[0]
# Out:
# Store                                                  Zudio
# Country                                                India
# State                                              Karnataka
# City                                                   Jalna
# Category                                               Women
# Clothing Type                                        Dresses
# Store Number                                              30
# Postal Code                                           411084
# Store Type                                             Owned
# Store Open Date                                   2022-06-04
# Selling Area Size (sq ft)                                950
# Store Manager                                      Lori Hill
# Manager ID                                               M77
# Store Address                PSC 4147, Box 1289 APO AA 19737
# Contact Information                        (014)392-4112x860
# ...

# %%
df.loc[8: ,['Order Date','State']]
# Out:
#       Order Date          State
# 8     2024-01-24      Karnataka
# 9     2024-02-02      Karnataka
# 10    2024-07-16    Maharashtra
# 11    2024-07-22  Uttar Pradesh
# 12    2024-05-17    Maharashtra
# ...          ...            ...
# 7894  2024-09-27  Uttar Pradesh
# 7895  2024-03-16  Uttar Pradesh
# 7896  2024-12-02     Tamil Nadu
# 7897  2024-07-29          Delhi
# 7898  2024-04-08        Gujarat
#
# [7891 rows x 2 columns]

# %%
df.iloc[0:25,2]
# Out:
# 0         Karnataka
# 1           Gujarat
# 2     Uttar Pradesh
# 3       West Bengal
# 4       West Bengal
# 5       West Bengal
# 6       Maharashtra
# 7       West Bengal
# 8         Karnataka
# 9         Karnataka
# 10      Maharashtra
# 11    Uttar Pradesh
# 12      Maharashtra
# 13          Gujarat
# 14       Tamil Nadu
# 15        Rajasthan
# 16      Maharashtra
# 17        Rajasthan
# 18        Rajasthan
# 19        Rajasthan
# 20       Tamil Nadu
# 21            Delhi
# 22          Gujarat
# 23      West Bengal
# 24        Karnataka
# Name: State, dtype: object

# %%
df.iloc[0:23,[14,17,20]]
# Out:
#        Contact Information Parking Availability  Order Date
# 0        (014)392-4112x860        Not Available  2024-11-06
# 1          +1-838-710-2029        Not Available  2024-06-17
# 2       523.732.1176x07696        Not Available  2024-08-17
# 3    +1-846-657-3934x68953        Not Available  2024-03-27
# 4            (336)147-6341        Not Available  2024-04-08
# 5          +1-149-000-5823            Available  2024-04-25
# 6     +1-886-886-9185x9650            Available  2024-06-19
# 7            (646)899-9850            Available  2024-06-11
# 8        (337)998-4800x283            Available  2024-01-24
# 9      (315)462-2864x05458            Available  2024-02-02
# 10    001-666-518-4316x287            Available  2024-07-16
# 11            535-871-6788            Available  2024-07-22
# 12  001-190-519-8370x89059        Not Available  2024-05-17
# 13    +1-579-715-4264x6243            Available  2024-05-20
# 14   +1-681-005-5756x68861        Not Available  2024-10-26
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.rename(columns={'Store':'Store_Name'},inplace=True)
df
# Out:
#      Store_Name Country          State        City Category Clothing Type  \
# 0         Zudio   India      Karnataka       Jalna    Women       Dresses
# 1         Zudio   India        Gujarat       Patna     Kids        Skirts
# 2         Zudio   India  Uttar Pradesh     Kolkata      Men       Hoodies
# 3         Zudio   India    West Bengal     Kolkata    Women       Dresses
# 4         Zudio   India    West Bengal    Guwahati      Men       Dresses
# ...         ...     ...            ...         ...      ...           ...
# 7894      Zudio   India  Uttar Pradesh  Chandigarh     Kids         Jeans
# 7895      Zudio   India  Uttar Pradesh  Aurangabad     Kids       Jackets
# 7896      Zudio   India     Tamil Nadu        Pune     Kids      T-shirts
# 7897      Zudio   India          Delhi     Madurai      Men         Shoes
# 7898      Zudio   India        Gujarat   Bengaluru    Women        Shirts
#
#       Store Number  Postal Code Store Type Store Open Date  ...  \
# ...

# %%
df['Store Open Date']
# Out:
# 0       2022-06-04
# 1       2020-12-19
# 2       2023-09-04
# 3       2024-04-11
# 4       2022-05-29
#            ...
# 7894    2024-04-24
# 7895    2024-02-03
# 7896    2021-04-11
# 7897    2022-06-17
# 7898    2023-02-08
# Name: Store Open Date, Length: 7899, dtype: object

# %%
df['Store Open Date'  ]=pd.to_datetime(df['Store Open Date'])
df
# Out:
#      Store_Name Country          State        City Category Clothing Type  \
# 0         Zudio   India      Karnataka       Jalna    Women       Dresses
# 1         Zudio   India        Gujarat       Patna     Kids        Skirts
# 2         Zudio   India  Uttar Pradesh     Kolkata      Men       Hoodies
# 3         Zudio   India    West Bengal     Kolkata    Women       Dresses
# 4         Zudio   India    West Bengal    Guwahati      Men       Dresses
# ...         ...     ...            ...         ...      ...           ...
# 7894      Zudio   India  Uttar Pradesh  Chandigarh     Kids         Jeans
# 7895      Zudio   India  Uttar Pradesh  Aurangabad     Kids       Jackets
# 7896      Zudio   India     Tamil Nadu        Pune     Kids      T-shirts
# 7897      Zudio   India          Delhi     Madurai      Men         Shoes
# 7898      Zudio   India        Gujarat   Bengaluru    Women        Shirts
#
#       Store Number  Postal Code Store Type Store Open Date  ...  \
# ...

# %% [markdown]
# task

# %%
import pandas as pd
df=pd.read_csv('/content/Zudio_sales_data.csv')
df
# Out:
#       Store Country          State        City Category Clothing Type  \
# 0     Zudio   India      Karnataka       Jalna    Women       Dresses
# 1     Zudio   India        Gujarat       Patna     Kids        Skirts
# 2     Zudio   India  Uttar Pradesh     Kolkata      Men       Hoodies
# 3     Zudio   India    West Bengal     Kolkata    Women       Dresses
# 4     Zudio   India    West Bengal    Guwahati      Men       Dresses
# ...     ...     ...            ...         ...      ...           ...
# 7894  Zudio   India  Uttar Pradesh  Chandigarh     Kids         Jeans
# 7895  Zudio   India  Uttar Pradesh  Aurangabad     Kids       Jackets
# 7896  Zudio   India     Tamil Nadu        Pune     Kids      T-shirts
# 7897  Zudio   India          Delhi     Madurai      Men         Shoes
# 7898  Zudio   India        Gujarat   Bengaluru    Women        Shirts
#
#       Store Number  Postal Code Store Type Store Open Date  ...  \
# ...

# %%
df.head()
# Out:
#    Store Country          State      City Category Clothing Type  \
# 0  Zudio   India      Karnataka     Jalna    Women       Dresses
# 1  Zudio   India        Gujarat     Patna     Kids        Skirts
# 2  Zudio   India  Uttar Pradesh   Kolkata      Men       Hoodies
# 3  Zudio   India    West Bengal   Kolkata    Women       Dresses
# 4  Zudio   India    West Bengal  Guwahati      Men       Dresses
#
#    Store Number  Postal Code Store Type Store Open Date  ...  \
# 0            30       411084      Owned      2022-06-04  ...
# 1            48       404562      Owned      2020-12-19  ...
# 2            97       437773     Rented      2023-09-04  ...
# 3            93       431725      Owned      2024-04-11  ...
# 4            51       415370      Owned      2022-05-29  ...
#
#    Security Features Order ID  Order Date     Month Customer ID  \
# 0              Alarm    88240  2024-11-06  November      233084
# 1              Alarm    78145  2024-06-17      June      926472
# ...

# %%
df.tail()
# Out:
#       Store Country          State        City Category Clothing Type  \
# 7894  Zudio   India  Uttar Pradesh  Chandigarh     Kids         Jeans
# 7895  Zudio   India  Uttar Pradesh  Aurangabad     Kids       Jackets
# 7896  Zudio   India     Tamil Nadu        Pune     Kids      T-shirts
# 7897  Zudio   India          Delhi     Madurai      Men         Shoes
# 7898  Zudio   India        Gujarat   Bengaluru    Women        Shirts
#
#       Store Number  Postal Code Store Type Store Open Date  ...  \
# 7894            32       431437      Owned      2024-04-24  ...
# 7895            52       424643      Owned      2024-02-03  ...
# 7896            81       412057      Owned      2021-04-11  ...
# 7897            58       405203     Rented      2022-06-17  ...
# 7898            20       429823      Owned      2023-02-08  ...
#
#       Security Features Order ID  Order Date      Month Customer ID  \
# 7894        CCTV, Alarm    39056  2024-09-27  September      591993
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7899 entries, 0 to 7898
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Store                      7899 non-null   object
#  1   Country                    7899 non-null   object
#  2   State                      7899 non-null   object
#  3   City                       7899 non-null   object
#  4   Category                   7899 non-null   object
#  5   Clothing Type              7899 non-null   object
#  6   Store Number               7899 non-null   int64
#  7   Postal Code                7899 non-null   int64
#  8   Store Type                 7899 non-null   object
#  9   Store Open Date            7899 non-null   object
#  10  Selling Area Size (sq ft)  7899 non-null   int64
#  11  Store Manager              7899 non-null   object
#  12  Manager ID                 7899 non-null   object
# ...

# %%
df.shape
# Out:
# (7899, 28)

# %%
df.columns
# Out:
# Index(['Store', 'Country', 'State', 'City', 'Category', 'Clothing Type',
#        'Store Number', 'Postal Code', 'Store Type', 'Store Open Date',
#        'Selling Area Size (sq ft)', 'Store Manager', 'Manager ID',
#        'Store Address', 'Contact Information', 'Operating Hours',
#        'Staff Count', 'Parking Availability', 'Security Features', 'Order ID',
#        'Order Date', 'Month', 'Customer ID', 'Customer Name', 'Product ID',
#        'Price', 'Quantity', 'Sales Profit'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Store Number    Postal Code  Selling Area Size (sq ft)  Staff Count  \
# count   7899.000000    7899.000000                7899.000000  7899.000000
# mean      50.666034  419982.374984                1112.077478    11.504747
# std       29.095274   11695.237817                 193.239371     5.194722
# min        1.000000  400006.000000                 800.000000     3.000000
# 25%       25.000000  409841.000000                 950.000000     7.000000
# 50%       51.000000  419988.000000                1100.000000    12.000000
# 75%       76.000000  430258.000000                1300.000000    16.000000
# max      100.000000  439985.000000                1400.000000    20.000000
#
#            Order ID    Customer ID   Product ID        Price     Quantity  \
# count   7899.000000    7899.000000  7899.000000  7899.000000  7899.000000
# mean   54920.719965  549440.714521   602.069376  1761.113432     4.519433
# ...

# %%
df.isnull()
# Out:
#       Store  Country  State   City  Category  Clothing Type  Store Number  \
# 0     False    False  False  False     False          False         False
# 1     False    False  False  False     False          False         False
# 2     False    False  False  False     False          False         False
# 3     False    False  False  False     False          False         False
# 4     False    False  False  False     False          False         False
# ...     ...      ...    ...    ...       ...            ...           ...
# 7894  False    False  False  False     False          False         False
# 7895  False    False  False  False     False          False         False
# 7896  False    False  False  False     False          False         False
# 7897  False    False  False  False     False          False         False
# 7898  False    False  False  False     False          False         False
#
#       Postal Code  Store Type  Store Open Date  ...  Security Features  \
# ...

# %%
df.isnull().sum()
# Out:
# Store                           0
# Country                         0
# State                           0
# City                            0
# Category                        0
# Clothing Type                   0
# Store Number                    0
# Postal Code                     0
# Store Type                      0
# Store Open Date                 0
# Selling Area Size (sq ft)       0
# Store Manager                   0
# Manager ID                      0
# Store Address                   0
# Contact Information             0
# Operating Hours                 0
# Staff Count                     0
# Parking Availability            0
# Security Features            2038
# Order ID                        0
# Order Date                      0
# Month                           0
# Customer ID                     0
# Customer Name                   0
# Product ID                      0
# Price                           0
# Quantity                        0
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7894    False
# 7895    False
# 7896    False
# 7897    False
# 7898    False
# Length: 7899, dtype: bool

# %%
df['Store']
# Out:
# 0       Zudio
# 1       Zudio
# 2       Zudio
# 3       Zudio
# 4       Zudio
#         ...
# 7894    Zudio
# 7895    Zudio
# 7896    Zudio
# 7897    Zudio
# 7898    Zudio
# Name: Store, Length: 7899, dtype: object

# %%
df[['Store','City']]
# Out:
#       Store        City
# 0     Zudio       Jalna
# 1     Zudio       Patna
# 2     Zudio     Kolkata
# 3     Zudio     Kolkata
# 4     Zudio    Guwahati
# ...     ...         ...
# 7894  Zudio  Chandigarh
# 7895  Zudio  Aurangabad
# 7896  Zudio        Pune
# 7897  Zudio     Madurai
# 7898  Zudio   Bengaluru
#
# [7899 rows x 2 columns]

# %%
df[['Store','City','Postal Code']]
# Out:
#       Store        City  Postal Code
# 0     Zudio       Jalna       411084
# 1     Zudio       Patna       404562
# 2     Zudio     Kolkata       437773
# 3     Zudio     Kolkata       431725
# 4     Zudio    Guwahati       415370
# ...     ...         ...          ...
# 7894  Zudio  Chandigarh       431437
# 7895  Zudio  Aurangabad       424643
# 7896  Zudio        Pune       412057
# 7897  Zudio     Madurai       405203
# 7898  Zudio   Bengaluru       429823
#
# [7899 rows x 3 columns]

# %%
df[5:]
# Out:
#       Store Country          State        City Category Clothing Type  \
# 5     Zudio   India    West Bengal      Nashik     Kids       Jackets
# 6     Zudio   India    Maharashtra     Lucknow     Kids       Jackets
# 7     Zudio   India    West Bengal   Hyderabad    Women          Tops
# 8     Zudio   India      Karnataka   Ahmedabad      Men         Shoes
# 9     Zudio   India      Karnataka   Hyderabad     Kids         Jeans
# ...     ...     ...            ...         ...      ...           ...
# 7894  Zudio   India  Uttar Pradesh  Chandigarh     Kids         Jeans
# 7895  Zudio   India  Uttar Pradesh  Aurangabad     Kids       Jackets
# 7896  Zudio   India     Tamil Nadu        Pune     Kids      T-shirts
# 7897  Zudio   India          Delhi     Madurai      Men         Shoes
# 7898  Zudio   India        Gujarat   Bengaluru    Women        Shirts
#
#       Store Number  Postal Code Store Type Store Open Date  ...  \
# ...

# %%
df[5:26]
# Out:
#     Store Country          State          City Category Clothing Type  \
# 5   Zudio   India    West Bengal        Nashik     Kids       Jackets
# 6   Zudio   India    Maharashtra       Lucknow     Kids       Jackets
# 7   Zudio   India    West Bengal     Hyderabad    Women          Tops
# 8   Zudio   India      Karnataka     Ahmedabad      Men         Shoes
# 9   Zudio   India      Karnataka     Hyderabad     Kids         Jeans
# 10  Zudio   India    Maharashtra       Kolkata      Men       Hoodies
# 11  Zudio   India  Uttar Pradesh        Nashik      Men       Jackets
# 12  Zudio   India    Maharashtra     Faridabad     Kids         Pants
# 13  Zudio   India        Gujarat         Noida     Kids        Skirts
# 14  Zudio   India     Tamil Nadu       Madurai     Kids      Sweaters
# 15  Zudio   India      Rajasthan         Noida    Women       Dresses
# 16  Zudio   India    Maharashtra  Chhattisgarh      Men         Pants
# ...

# %%
df['State'].value_counts()
# Out:
# State
# Rajasthan        1013
# Uttar Pradesh    1011
# Delhi            1011
# Gujarat           982
# West Bengal       982
# Maharashtra       975
# Karnataka         963
# Tamil Nadu        962
# Name: count, dtype: int64

# %%
df['State'].unique()
# Out:
# array(['Karnataka', 'Gujarat', 'Uttar Pradesh', 'West Bengal',
#        'Maharashtra', 'Tamil Nadu', 'Rajasthan', 'Delhi'], dtype=object)

# %%
df['State'].nunique()
# Out:
# 8

# %%
df.loc[0]
# Out:
# Store                                                  Zudio
# Country                                                India
# State                                              Karnataka
# City                                                   Jalna
# Category                                               Women
# Clothing Type                                        Dresses
# Store Number                                              30
# Postal Code                                           411084
# Store Type                                             Owned
# Store Open Date                                   2022-06-04
# Selling Area Size (sq ft)                                950
# Store Manager                                      Lori Hill
# Manager ID                                               M77
# Store Address                PSC 4147, Box 1289 APO AA 19737
# Contact Information                        (014)392-4112x860
# ...

# %%
df.loc[25,['Order Date']]
# Out:
# Order Date    2024-01-18
# Name: 25, dtype: object

# %%
df.loc[8:,['State','Order Date']]
# Out:
#               State  Order Date
# 8         Karnataka  2024-01-24
# 9         Karnataka  2024-02-02
# 10      Maharashtra  2024-07-16
# 11    Uttar Pradesh  2024-07-22
# 12      Maharashtra  2024-05-17
# ...             ...         ...
# 7894  Uttar Pradesh  2024-09-27
# 7895  Uttar Pradesh  2024-03-16
# 7896     Tamil Nadu  2024-12-02
# 7897          Delhi  2024-07-29
# 7898        Gujarat  2024-04-08
#
# [7891 rows x 2 columns]

# %%
df.iloc[0:25,2]
# Out:
# 0         Karnataka
# 1           Gujarat
# 2     Uttar Pradesh
# 3       West Bengal
# 4       West Bengal
# 5       West Bengal
# 6       Maharashtra
# 7       West Bengal
# 8         Karnataka
# 9         Karnataka
# 10      Maharashtra
# 11    Uttar Pradesh
# 12      Maharashtra
# 13          Gujarat
# 14       Tamil Nadu
# 15        Rajasthan
# 16      Maharashtra
# 17        Rajasthan
# 18        Rajasthan
# 19        Rajasthan
# 20       Tamil Nadu
# 21            Delhi
# 22          Gujarat
# 23      West Bengal
# 24        Karnataka
# Name: State, dtype: object

# %%
df.iloc[0:23,[14,17,20]]
# Out:
#        Contact Information Parking Availability  Order Date
# 0        (014)392-4112x860        Not Available  2024-11-06
# 1          +1-838-710-2029        Not Available  2024-06-17
# 2       523.732.1176x07696        Not Available  2024-08-17
# 3    +1-846-657-3934x68953        Not Available  2024-03-27
# 4            (336)147-6341        Not Available  2024-04-08
# 5          +1-149-000-5823            Available  2024-04-25
# 6     +1-886-886-9185x9650            Available  2024-06-19
# 7            (646)899-9850            Available  2024-06-11
# 8        (337)998-4800x283            Available  2024-01-24
# 9      (315)462-2864x05458            Available  2024-02-02
# 10    001-666-518-4316x287            Available  2024-07-16
# 11            535-871-6788            Available  2024-07-22
# 12  001-190-519-8370x89059        Not Available  2024-05-17
# 13    +1-579-715-4264x6243            Available  2024-05-20
# 14   +1-681-005-5756x68861        Not Available  2024-10-26
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.rename(columns={'Store':'Store_name'},inplace=True)
df
# Out:
#      Store_name Country          State        City Category Clothing Type  \
# 0         Zudio   India      Karnataka       Jalna    Women       Dresses
# 1         Zudio   India        Gujarat       Patna     Kids        Skirts
# 2         Zudio   India  Uttar Pradesh     Kolkata      Men       Hoodies
# 3         Zudio   India    West Bengal     Kolkata    Women       Dresses
# 4         Zudio   India    West Bengal    Guwahati      Men       Dresses
# ...         ...     ...            ...         ...      ...           ...
# 7894      Zudio   India  Uttar Pradesh  Chandigarh     Kids         Jeans
# 7895      Zudio   India  Uttar Pradesh  Aurangabad     Kids       Jackets
# 7896      Zudio   India     Tamil Nadu        Pune     Kids      T-shirts
# 7897      Zudio   India          Delhi     Madurai      Men         Shoes
# 7898      Zudio   India        Gujarat   Bengaluru    Women        Shirts
#
#       Store Number  Postal Code Store Type Store Open Date  ...  \
# ...

# %%
df['Store Open Date']
# Out:
# 0       2022-06-04
# 1       2020-12-19
# 2       2023-09-04
# 3       2024-04-11
# 4       2022-05-29
#            ...
# 7894    2024-04-24
# 7895    2024-02-03
# 7896    2021-04-11
# 7897    2022-06-17
# 7898    2023-02-08
# Name: Store Open Date, Length: 7899, dtype: object

# %%
df['Store Open Date']=pd.to_datetime(df['Store Open Date'])
df
# Out:
#      Store_name Country          State        City Category Clothing Type  \
# 0         Zudio   India      Karnataka       Jalna    Women       Dresses
# 1         Zudio   India        Gujarat       Patna     Kids        Skirts
# 2         Zudio   India  Uttar Pradesh     Kolkata      Men       Hoodies
# 3         Zudio   India    West Bengal     Kolkata    Women       Dresses
# 4         Zudio   India    West Bengal    Guwahati      Men       Dresses
# ...         ...     ...            ...         ...      ...           ...
# 7894      Zudio   India  Uttar Pradesh  Chandigarh     Kids         Jeans
# 7895      Zudio   India  Uttar Pradesh  Aurangabad     Kids       Jackets
# 7896      Zudio   India     Tamil Nadu        Pune     Kids      T-shirts
# 7897      Zudio   India          Delhi     Madurai      Men         Shoes
# 7898      Zudio   India        Gujarat   Bengaluru    Women        Shirts
#
#       Store Number  Postal Code Store Type Store Open Date  ...  \
# ...

# %%
df['Store Open Date']
# Out:
# 0      2022-06-04
# 1      2020-12-19
# 2      2023-09-04
# 3      2024-04-11
# 4      2022-05-29
#           ...
# 7894   2024-04-24
# 7895   2024-02-03
# 7896   2021-04-11
# 7897   2022-06-17
# 7898   2023-02-08
# Name: Store Open Date, Length: 7899, dtype: datetime64[ns]

# %%
df['year']=df['Store Open Date'].dt.year
df['year']
# Out:
# 0       2022
# 1       2020
# 2       2023
# 3       2024
# 4       2022
#         ...
# 7894    2024
# 7895    2024
# 7896    2021
# 7897    2022
# 7898    2023
# Name: year, Length: 7899, dtype: int32

# %%
df['day']=df['Store Open Date'].dt.day
df['day']
# Out:
# 0        4
# 1       19
# 2        4
# 3       11
# 4       29
#         ..
# 7894    24
# 7895     3
# 7896    11
# 7897    17
# 7898     8
# Name: day, Length: 7899, dtype: int32

# %%
df['PROFIT_EST']=df['Sales Profit']*0.2
df['PROFIT_EST']
# Out:
# 0        783.20
# 1        166.24
# 2        231.20
# 3       1185.12
# 4        530.40
#          ...
# 7894     227.04
# 7895     290.24
# 7896     156.88
# 7897     650.88
# 7898    1109.20
# Name: PROFIT_EST, Length: 7899, dtype: float64

# %%
df.drop('PROFIT_EST',axis=1,inplace=True)

# %%
monthly_sales=df.groupby('Month')['Sales Profit'].sum()
print(monthly_sales)
# Out:
# Month
# April        2264574.4
# August       2318573.2
# December      233638.4
# February     2177634.8
# January      2304772.4
# July         2212031.2
# June         2170034.0
# March        2261135.6
# May          2245175.2
# November     2312898.4
# October      2372189.6
# September    2172476.0
# Name: Sales Profit, dtype: float64

# %%
monthly_sales.plot(kind='line')
# Out:
# <Axes: xlabel='Month'>

# %%
monthly_sales.plot(kind='bar')
# Out:
# <Axes: xlabel='Month'>

# %%
df.groupby('State')['Sales Profit'].sum()
# Out:
# State
# Delhi            3191315.6
# Gujarat          3050520.8
# Karnataka        3034747.6
# Maharashtra      3089685.6
# Rajasthan        3187911.6
# Tamil Nadu       3085623.2
# Uttar Pradesh    3163014.0
# West Bengal      3242314.8
# Name: Sales Profit, dtype: float64

# %%
orders_per_year=df.groupby('year')['Order ID'].nunique()
print(orders_per_year)
# Out:
# year
# 2020    1601
# 2021    1622
# 2022    1571
# 2023    1608
# 2024    1418
# Name: Order ID, dtype: int64

# %%
avg_sales_product=df.groupby('Product ID')['Sales Profit'].mean()
print(avg_sales_product)
# Out:
# Product ID
# 204    2518.925000
# 205    3046.033333
# 206    3735.288889
# 207    3274.618182
# 208    4270.040000
#           ...
# 995    3123.018182
# 996    2652.618182
# 997    2876.533333
# 998    4375.925000
# 999    2804.920000
# Name: Sales Profit, Length: 796, dtype: float64

# %%
df['State']
# Out:
# 0           Karnataka
# 1             Gujarat
# 2       Uttar Pradesh
# 3         West Bengal
# 4         West Bengal
#             ...
# 7894    Uttar Pradesh
# 7895    Uttar Pradesh
# 7896       Tamil Nadu
# 7897            Delhi
# 7898          Gujarat
# Name: State, Length: 7899, dtype: object

# %%
df['State']=df['State'].str.upper()
df['State']
# Out:
# 0           KARNATAKA
# 1             GUJARAT
# 2       UTTAR PRADESH
# 3         WEST BENGAL
# 4         WEST BENGAL
#             ...
# 7894    UTTAR PRADESH
# 7895    UTTAR PRADESH
# 7896       TAMIL NADU
# 7897            DELHI
# 7898          GUJARAT
# Name: State, Length: 7899, dtype: object

# %%
df.to_csv('clean_data.csv',index=False)
